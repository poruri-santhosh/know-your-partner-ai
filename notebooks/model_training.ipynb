# %% [markdown]
# # Know Your Partner AI: Model Training & Evaluation
#
# Train and compare Linear Regression, Random Forest, and Gradient Boosting regressors on pair behavioral difference vectors.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('../backend')))

from app.ml.train import train_models
results = train_models()
print("Training Summary:", results)
